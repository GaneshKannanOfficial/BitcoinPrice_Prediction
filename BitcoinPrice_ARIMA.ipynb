# %% [markdown]
# <a href="https://colab.research.google.com/github/GaneshKannanOfficial/BitcoinPrice_Prediction/blob/main/BitcoinPrice_ARIMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
df = yf.download('BTC-USD')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2023-09-13  25837.554688  26376.113281  25781.123047  26228.324219
# 2023-09-14  26228.277344  26774.623047  26171.451172  26539.673828
# 2023-09-15  26533.818359  26840.498047  26240.701172  26608.693359
# 2023-09-16  26606.199219  26754.769531  26473.890625  26568.281250
# 2023-09-17  26568.392578  26611.732422  26452.367188  26598.572266
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2023-09-13  26228.324219  13072077070
# 2023-09-14  26539.673828  13811359124
# 2023-09-15  26608.693359  11479735788
# 2023-09-16  26568.281250   7402031417
# 2023-09-17  26598.572266   6521905664
#
# [3288 rows x 6 columns]

# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt
import math
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
plt.plot(df.index,df['Adj Close'])
plt.show()

# %%
#Train test split

row = int(len(df)*0.9)
train_data = list(df[0:row]['Adj Close'])
test_data = list(df[row:]['Adj Close'])

# %%
plt.figure(figsize = (10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df.index[0:row],train_data,'green',label='Train data')
plt.plot(df.index[row:],test_data,'blue',label='Test data')
plt.legend()

# %%
model_pred = []
n_test = len(test_data)

# %%
for i in range(n_test):
  model = ARIMA(train_data,order=(4,1,0))
  model_fit = model.fit()
  out = model_fit.forecast()
  y_pred = out[0]
  model_pred.append(y_pred)
  test_val = test_data[i]
  train_data.append(test_val)

# %%
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3287
# Model:                 ARIMA(4, 1, 0)   Log Likelihood              -26545.417
# Date:                Sun, 17 Sep 2023   AIC                          53100.835
# Time:                        13:27:33   BIC                          53131.322
# Sample:                             0   HQIC                         53111.750
#                                - 3287
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0250      0.009     -2.753      0.006      -0.043      -0.007
# ar.L2          0.0084      0.009      0.960      0.337      -0.009       0.025
# ar.L3          0.0198      0.009      2.118      0.034       0.001       0.038
# ar.L4          0.0310      0.008      3.995      0.000       0.016       0.046
# sigma2      6.093e+05   4958.863    122.864      0.000       6e+05    6.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             39221.85
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):             513.55   Skew:                            -0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
plt.figure(figsize = (15,9))
plt.grid(True)
data_range = df.index[row:]
plt.plot(data_range,model_pred,color='blue',marker='o',linestyle='dashed',label = 'BTC predicted')
plt.plot(data_range,test_data,color='red',label = 'BTC actual')
plt.title('Bitcoin price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
